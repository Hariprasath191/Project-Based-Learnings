# %%
import numpy 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data.csv")

# %%
data.head(5)
# Out:
#    StudyTime  Score
# 0         12     46
# 1         15     50
# 2         18     54
# 3         20     57
# 4         22     60
